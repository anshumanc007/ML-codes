# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-20a8276d-2850-4ac4-afa1-66f6f941103d" name="files[]" multiple disabled />
#      <output id="result-20a8276d-2850-4ac4-afa1-66f6f941103d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-225-5c2e8a8d365b> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
#      66   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
import pandas as pd
data=pd.read_csv('Concrete_Data_Yeh.csv')
data
#from sklearn.utils import shuffle
#data = shuffle(data)
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 6      380.0   95.0     0.0  228.0               0.0            932.0
# 7      380.0   95.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# 9      475.0    0.0     0.0  228.0               0.0            932.0
# 10     198.6  132.4     0.0  192.0               0.0            978.4
# 11     198.6  132.4     0.0  192.0               0.0            978.4
# 12     427.5   47.5     0.0  228.0               0.0            932.0
# 13     190.0  190.0     0.0  228.0               0.0            932.0
# 14     304.0   76.0     0.0  228.0               0.0            932.0
# 15     380.0    0.0     0.0  228.0               0.0            932.0
# 16     139.6  209.4     0.0  192.0               0.0           1047.0
# 17     342.0   38.0     0.0  228.0               0.0            932.0
# 18     380.0   95.0     0.0  228.0               0.0            932.0
# 19     475.0    0.0     0.0  228.0               0.0            932.0
# 20     427.5   47.5     0.0  228.0               0.0            932.0
# 21     139.6  209.4     0.0  192.0               0.0           1047.0
# 22     139.6  209.4     0.0  192.0               0.0           1047.0
# 23     139.6  209.4     0.0  192.0               0.0           1047.0
# 24     380.0    0.0     0.0  228.0               0.0            932.0
# 25     380.0    0.0     0.0  228.0               0.0            932.0
# 26     380.0   95.0     0.0  228.0               0.0            932.0
# 27     342.0   38.0     0.0  228.0               0.0            932.0
# 28     427.5   47.5     0.0  228.0               0.0            932.0
# 29     475.0    0.0     0.0  228.0               0.0            932.0
# ...      ...    ...     ...    ...               ...              ...
# 1000   141.9  166.6   129.7  173.5              10.9            882.6
# 1001   297.8  137.2   106.9  201.3               6.0            878.4
# 1002   321.3  164.2     0.0  190.5               4.6            870.0
# 1003   366.0  187.0     0.0  191.3               6.6            824.3
# 1004   279.8  128.9   100.4  172.4               9.5            825.1
# 1005   252.1   97.1    75.6  193.8               8.3            835.5
# 1006   164.6    0.0   150.4  181.6              11.7           1023.3
# 1007   155.6  243.5     0.0  180.3              10.7           1022.0
# 1008   160.2  188.0   146.4  203.2              11.3            828.7
# 1009   298.1    0.0   107.0  186.4               6.1            879.0
# 1010   317.9    0.0   126.5  209.7               5.7            860.5
# 1011   287.3  120.5    93.9  187.6               9.2            904.4
# 1012   325.6  166.4     0.0  174.0               8.9            881.6
# 1013   355.9    0.0   141.6  193.3              11.0            801.4
# 1014   132.0  206.5   160.9  178.9               5.5            866.9
# 1015   322.5  148.6     0.0  185.8               8.5            951.0
# 1016   164.2    0.0   200.1  181.2              12.6            849.3
# 1017   313.8    0.0   112.6  169.9              10.1            925.3
# 1018   321.4    0.0   127.9  182.5              11.5            870.1
# 1019   139.7  163.9   127.7  236.7               5.8            868.6
# 1020   288.4  121.0     0.0  177.4               7.0            907.9
# 1021   298.2    0.0   107.0  209.7              11.1            879.6
# 1022   264.5  111.0    86.5  195.5               5.9            832.6
# 1023   159.8  250.0     0.0  168.4              12.2           1049.3
# 1024   166.0  259.7     0.0  183.2              12.7            858.8
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# 2             594.0  270  40.27
# 3             594.0  365  41.05
# 4             825.5  360  44.30
# 5             670.0   90  47.03
# 6             594.0  365  43.70
# 7             594.0   28  36.45
# 8             670.0   28  45.85
# 9             594.0   28  39.29
# 10            825.5   90  38.07
# 11            825.5   28  28.02
# 12            594.0  270  43.01
# 13            670.0   90  42.33
# 14            670.0   28  47.81
# 15            670.0   90  52.91
# 16            806.9   90  39.36
# 17            670.0  365  56.14
# 18            594.0   90  40.56
# 19            594.0  180  42.62
# 20            594.0  180  41.84
# 21            806.9   28  28.24
# 22            806.9    3   8.06
# 23            806.9  180  44.21
# 24            670.0  365  52.52
# 25            670.0  270  53.30
# 26            594.0  270  41.15
# 27            670.0  180  52.12
# 28            594.0   28  37.43
# 29            594.0    7  38.60
# ...             ...  ...    ...
# 1000          785.3   28  44.61
# 1001          655.3   28  53.52
# 1002          774.0   28  57.22
# 1003          756.9   28  65.91
# 1004          804.9   28  52.83
# 1005          821.4   28  33.40
# 1006          728.9   28  18.03
# 1007          697.7   28  37.36
# 1008          709.7   28  35.31
# 1009          815.2   28  42.64
# 1010          736.6   28  40.06
# 1011          695.9   28  43.80
# 1012          790.0   28  61.24
# 1013          778.4   28  40.87
# 1014          735.6   28  33.31
# 1015          709.5   28  52.43
# 1016          846.0   28  15.09
# 1017          782.9   28  38.46
# 1018          779.7   28  37.27
# 1019          655.6   28  35.23
# 1020          829.5   28  42.14
# 1021          744.2   28  31.88
# 1022          790.4   28  41.54
# 1023          688.2   28  39.46
# 1024          826.8   28  37.92
# 1025          768.3   28  44.28
# 1026          813.4   28  31.18
# 1027          780.0   28  23.70
# 1028          788.9   28  32.77
# 1029          761.5   28  32.40
#
# [1030 rows x 9 columns]

# %%
#forming inp & op
X=data.iloc[ :, :-1].values
Y=data.iloc[:,-1].values
#Y=Y-1

# %%
import numpy as np

# %%
#spilliting test and train data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.fit_transform(X_test)

# %%
m_train=X_train.shape[0];
m_test=X_test.shape[0];
feat=X_train.shape[1];

# %%
def initialise(dim):
  W=np.random.rand(dim,1)
  b=0.00
  return W,b

# %%
def propagate(W,b,X,Y):
  m=X.shape[1]
  A=(np.dot(W.T,X)+b);
  cost=1/(2*m)*np.sum((A-Y)**2);
  dW=1/m*np.dot(X,(A-Y).T);
  db=1/m*np.sum(A-Y);
  grads = {"dW": dW,
             "db": db};
  return grads,cost;

# %%
def optimise(W,b,X,Y,num_iteration,alpha):
  costs=[]
  for i in range(num_iteration):
    grads,cost=propagate(W,b,X,Y)
    dW=grads['dW'];
    db=grads['db'];
    W=W-alpha*dW;
    b=b-alpha*db;
    costs.append(cost);
    #if (i%100==0):
     # print(cost)
    
  parameters={"W": W,
                "b":b
              
               }
  gradients={"dW":dW,
               "db":db}
   
  return parameters,gradients

# %%
def prediction(W,b,X):
  m=X.shape[1];
  A=np.dot(W.T,X)+b;     
  return A;

# %%
def model(X_train,Y_train,X_test,Y_test,num_iteration,alpha):
  mini=100000;
  for i in range(100):
    W,b=initialise(X_train.shape[0])
    parameters, grads = optimise(W, b, X_train, Y_train, num_iteration,alpha)
    W=parameters['W'];
    b=parameters['b'];
    Y_prediction_test = prediction(W, b, X_test)
    Y_prediction_train = prediction(W,b,X_train)
    m=X_test.shape[1]
    error=1/m*np.sum((Y_prediction_test-Y_test)**2)
    if(error<mini):
      mini=error
  
    
  d = {  "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
          "error" : mini,
         "W" : W, 
         "b" : b,
         "learning_rate" : alpha,
         "num_iterations": num_iteration};
  return d;

# %%
d = model(X_train.T, Y_train.T, X_test.T ,Y_test.T, num_iteration = 1000, alpha=0.5)
print (d["error"])
# Out:
# 112.71652264743864
